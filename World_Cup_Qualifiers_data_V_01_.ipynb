# %% [markdown]
# <a href="https://colab.research.google.com/github/YahiaML/World-Cup-Qualifiers-data/blob/main/World_Cup_Qualifiers_data_V_01_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Importing libraries**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ##**Scraping Africa Data**

# %%
response = requests.get('https://fbref.com/en/comps/2/WCQ----CAF-M-Stats')
data = response.text
soup = BeautifulSoup(data,"html.parser")

# %%
Teams_stats = soup.find_all('tr')

teams_data = []

for team in Teams_stats:

  team_data = []
  Team_stats = team.find_all("td")

  for team in Team_stats:

    #print(team.text)
    team_data.append(team.text)

  teams_data.append(team_data)

# %%
teams_data
# Out:
# [[],
#  ['dz Algeria', '6', '4', '2', '0', '25', '4', '+21', '14', '→ Third round '],
#  ['bf Burkina Faso', '6', '3', '3', '0', '12', '4', '+8', '12', ''],
#  ['ne Niger', '6', '2', '1', '3', '13', '17', '-4', '7', ''],
#  ['dj Djibouti', '6', '0', '0', '6', '4', '29', '-25', '0', ''],
#  [],
#  ['tn Tunisia', '6', '4', '1', '1', '11', '2', '+9', '13', '→ Third round '],
#  ['gq Equ. Guinea', '6', '3', '2', '1', '6', '5', '+1', '11', ''],
#  ['zm Zambia', '6', '2', '1', '3', '8', '9', '-1', '7', ''],
#  ['mr Mauritania', '6', '0', '2', '4', '2', '11', '-9', '2', ''],
#  [],
#  ['ng Nigeria', '6', '4', '1', '1', '9', '3', '+6', '13', '→ Third round '],
#  ['cv Cape Verde', '6', '3', '2', '1', '8', '6', '+2', '11', ''],
#  ['lr Liberia', '6', '2', '0', '4', '5', '8', '-3', '6', ''],
#  ['cf CAR', '6', '1', '1', '4', '4', '9', '-5', '4', ''],
#  [],
#  ['cm Cameroon', '6', '5', '0', '1', '12', '3', '+9', '15', '→ Third round '],
# ...

# %%
teams_data = [list_ for list_ in teams_data if list_ != []]

# %%
teams_data
# Out:
# [['dz Algeria', '6', '4', '2', '0', '25', '4', '+21', '14', '→ Third round '],
#  ['bf Burkina Faso', '6', '3', '3', '0', '12', '4', '+8', '12', ''],
#  ['ne Niger', '6', '2', '1', '3', '13', '17', '-4', '7', ''],
#  ['dj Djibouti', '6', '0', '0', '6', '4', '29', '-25', '0', ''],
#  ['tn Tunisia', '6', '4', '1', '1', '11', '2', '+9', '13', '→ Third round '],
#  ['gq Equ. Guinea', '6', '3', '2', '1', '6', '5', '+1', '11', ''],
#  ['zm Zambia', '6', '2', '1', '3', '8', '9', '-1', '7', ''],
#  ['mr Mauritania', '6', '0', '2', '4', '2', '11', '-9', '2', ''],
#  ['ng Nigeria', '6', '4', '1', '1', '9', '3', '+6', '13', '→ Third round '],
#  ['cv Cape Verde', '6', '3', '2', '1', '8', '6', '+2', '11', ''],
#  ['lr Liberia', '6', '2', '0', '4', '5', '8', '-3', '6', ''],
#  ['cf CAR', '6', '1', '1', '4', '4', '9', '-5', '4', ''],
#  ['cm Cameroon', '6', '5', '0', '1', '12', '3', '+9', '15', '→ Third round '],
#  ["ci Côte d'Ivoire", '6', '4', '1', '1', '10', '3', '+7', '13', ''],
# ...

# %%
for team in teams_data:
  team[0] = team[0][3:]

# %%
teams_data
# Out:
# [['Algeria', '6', '4', '2', '0', '25', '4', '+21', '14', '→ Third round '],
#  ['Burkina Faso', '6', '3', '3', '0', '12', '4', '+8', '12', ''],
#  ['Niger', '6', '2', '1', '3', '13', '17', '-4', '7', ''],
#  ['Djibouti', '6', '0', '0', '6', '4', '29', '-25', '0', ''],
#  ['Tunisia', '6', '4', '1', '1', '11', '2', '+9', '13', '→ Third round '],
#  ['Equ. Guinea', '6', '3', '2', '1', '6', '5', '+1', '11', ''],
#  ['Zambia', '6', '2', '1', '3', '8', '9', '-1', '7', ''],
#  ['Mauritania', '6', '0', '2', '4', '2', '11', '-9', '2', ''],
#  ['Nigeria', '6', '4', '1', '1', '9', '3', '+6', '13', '→ Third round '],
#  ['Cape Verde', '6', '3', '2', '1', '8', '6', '+2', '11', ''],
#  ['Liberia', '6', '2', '0', '4', '5', '8', '-3', '6', ''],
#  ['CAR', '6', '1', '1', '4', '4', '9', '-5', '4', ''],
#  ['Cameroon', '6', '5', '0', '1', '12', '3', '+9', '15', '→ Third round '],
#  ["Côte d'Ivoire", '6', '4', '1', '1', '10', '3', '+7', '13', ''],
# ...

# %%
teams_data = pd.DataFrame(teams_data, columns = ['Squad',	'MP',	'W',	'D',	'L',	'GF',	'GA',	'GD', 'Pts', 'Notes'])  # inserting columns names
teams_data
# Out:
#             Squad MP  W  D  L  GF  GA   GD Pts           Notes
# 0         Algeria  6  4  2  0  25   4  +21  14  → Third round
# 1    Burkina Faso  6  3  3  0  12   4   +8  12
# 2           Niger  6  2  1  3  13  17   -4   7
# 3        Djibouti  6  0  0  6   4  29  -25   0
# 4         Tunisia  6  4  1  1  11   2   +9  13  → Third round
# 5     Equ. Guinea  6  3  2  1   6   5   +1  11
# 6          Zambia  6  2  1  3   8   9   -1   7
# 7      Mauritania  6  0  2  4   2  11   -9   2
# 8         Nigeria  6  4  1  1   9   3   +6  13  → Third round
# 9      Cape Verde  6  3  2  1   8   6   +2  11
# 10        Liberia  6  2  0  4   5   8   -3   6
# 11            CAR  6  1  1  4   4   9   -5   4
# 12       Cameroon  6  5  0  1  12   3   +9  15  → Third round
# 13  Côte d'Ivoire  6  4  1  1  10   3   +7  13
# 14     Mozambique  6  1  1  4   2   8   -6   4
# 15         Malawi  6  1  0  5   2  12  -10   3
# 16           Mali  6  5  1  0  11   0  +11  16  → Third round
# ...
